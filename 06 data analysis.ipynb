# %% [markdown]
# ##### array

# %%
import numpy as np

# %%
num = np.array([67, 12, 89, 32, 12, 42])

# %%
num
# Out:
# array([67, 12, 89, 32, 12, 42])

# %%
num.dtype
# Out:
# dtype('int64')

# %%
num[5]
# Out:
# 42

# %%
num = np.array([67, 12, 89, 32, 12, 42], dtype=np.int16)

# %%
num
# Out:
# array([67, 12, 89, 32, 12, 42], dtype=int16)

# %%
num * 2
# Out:
# array([134,  24, 178,  64,  24,  84], dtype=int16)

# %% [markdown]
# ##### Series

# %%
import pandas as pd

# %%
s = pd.Series([67, 12, 89, 32, 12, 42])

# %%
s
# Out:
# 0    67
# 1    12
# 2    89
# 3    32
# 4    12
# 5    42
# dtype: int64

# %% [markdown]
# ##### DataFrame

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series(['anita','raja','priya','nakul','ajey'])
s3 = pd.Series([67.89, 45.56, 87.56, 75.45, 61.56])

# %%
df = pd.DataFrame({
    'roll': s1,
    'name': s2,
    'marks': s3
})

# %%
df
# Out:
#    roll   name  marks
# 0     1  anita  67.89
# 1     2   raja  45.56
# 2     3  priya  87.56
# 3     4  nakul  75.45
# 4     5   ajey  61.56

# %% [markdown]
# ##### Dataset

# %% [markdown]
# https://mitu.co.in/dataset
# Download -> bank-customers.csv   and store in current working directory

# %%
# How to find current working directory?
import os
os.getcwd()
# Out:
# '/home/mitu/ssbf-aug25'

# %%
df = pd.read_csv('bank-customers.csv')

# %%
df
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 0         C001     Rajesh    Sharma    1985-04-12    Male
# 1         C002      Priya   Satpute    1992-07-25  Female
# 2         C003       Amit     Kumar    1978-11-01    Male
# 3         C004     Anjali     Mehta    1995-02-18  Female
# 4         C005    Sandeep     Verma    1980-06-30    Male
# 5         C006       Neha     Joshi    1990-09-05  Female
# 6         C007     Vikram     Patel    1975-03-20    Male
# 7         C008      Sonia       Das    1988-10-10  Female
# 8         C009      Arjun     Yadav    1998-05-15    Male
# 9         C010    Deepika     Reddy    1991-01-20  Female
# 10        C011      Rahul     Gupta    1983-04-05    Male
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 12        C013     Mahesh     Dubey    1970-12-25    Male
# 13        C014      Pooja       Rao    1987-03-22  Female
# 14        C015      Vinay     Meena    1996-06-05    Male
# ...

# %%
df.shape
# Out:
# (20, 24)

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'date_of_birth', 'gender',
#        'email_address', 'phone_number', 'address_line1', 'city', 'state',
#        'postal_code', 'country', 'account_number', 'account_type',
#        'account_open_date', 'account_status', 'current_balance',
#        'balance_date', 'last_activity_date', 'total_deposits_ytd',
#        'total_withdrawals_ytd', 'average_monthly_balance',
#        'number_of_transactions_ytd', 'average_transaction_value'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customer_id                    object
# first_name                     object
# last_name                      object
# date_of_birth                  object
# gender                         object
# email_address                  object
# phone_number                    int64
# address_line1                  object
# city                           object
# state                          object
# postal_code                    object
# country                         int64
# account_number                 object
# account_type                   object
# account_open_date              object
# account_status                 object
# current_balance                object
# balance_date                  float64
# last_activity_date             object
# total_deposits_ytd             object
# total_withdrawals_ytd           int64
# average_monthly_balance         int64
# number_of_transactions_ytd      int64
# average_transaction_value       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 20 non-null     object
#  1   first_name                  20 non-null     object
#  2   last_name                   20 non-null     object
#  3   date_of_birth               20 non-null     object
#  4   gender                      20 non-null     object
#  5   email_address               20 non-null     object
#  6   phone_number                20 non-null     int64
#  7   address_line1               20 non-null     object
#  8   city                        20 non-null     object
#  9   state                       20 non-null     object
#  10  postal_code                 20 non-null     object
#  11  country                     20 non-null     int64
#  12  account_number              20 non-null     object
# ...

# %%
df.head()
# Out:
#   customer_id first_name last_name date_of_birth  gender  \
# 0        C001     Rajesh    Sharma    1985-04-12    Male
# 1        C002      Priya   Satpute    1992-07-25  Female
# 2        C003       Amit     Kumar    1978-11-01    Male
# 3        C004     Anjali     Mehta    1995-02-18  Female
# 4        C005    Sandeep     Verma    1980-06-30    Male
#
#              email_address  phone_number address_line1          city  \
# 0  rajesh.sharma@email.com  919876543210            12     Sector 15
# 1  priya.satpute@email.com  919988776655            4B  Gandhi Nagar
# 2         amit.k@email.com  919765432109             7   Park Street
# 3   anjali.mehta@email.com  919123456789            21   Indiranagar
# 4      sandeep.v@email.com  918877665544             8    Model Town
#
#        state  ... account_open_date  account_status current_balance  \
# 0   Gurugram  ...          Checking      2010-01-20          Active
# ...

# %%
df.head(3)
# Out:
#   customer_id first_name last_name date_of_birth  gender  \
# 0        C001     Rajesh    Sharma    1985-04-12    Male
# 1        C002      Priya   Satpute    1992-07-25  Female
# 2        C003       Amit     Kumar    1978-11-01    Male
#
#              email_address  phone_number address_line1          city  \
# 0  rajesh.sharma@email.com  919876543210            12     Sector 15
# 1  priya.satpute@email.com  919988776655            4B  Gandhi Nagar
# 2         amit.k@email.com  919765432109             7   Park Street
#
#       state  ... account_open_date  account_status current_balance  \
# 0  Gurugram  ...          Checking      2010-01-20          Active
# 1      Pune  ...           Savings      2015-05-10          Active
# 2   Kolkata  ...       Credit Card      2005-09-08          Active
#
#   balance_date last_activity_date total_deposits_ytd total_withdrawals_ytd  \
# 0     85000.50         2025-08-29         2025-08-28                250000
# ...

# %%
df.tail()
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 15        C016      Priya       Das    1993-02-28  Female
# 16        C017      Akash   Mahadik    1989-10-15    Male
# 17        C018       Ritu    Saxena    1984-01-08  Female
# 18        C019      Vivek     Yadav    1997-09-02    Male
# 19        C020    Sanjana     Singh    1990-04-14  Female
#
#           email_address  phone_number address_line1          city       state  \
# 15  priya.das@email.com  918210987654            19    Anna Nagar     Chennai
# 16    akash.m@email.com  918109876543             6  Adarsh Nagar      Mumbai
# 17     ritu.s@email.com  918098765432            2B   Vikas Nagar      Kanpur
# 18    vivek.y@email.com  917987654321            21      Sector 4  Chandigarh
# 19  sanjana.s@email.com  917890123456             1   Ashok Vihar       Delhi
#
#     ... account_open_date  account_status current_balance balance_date  \
# 15  ...           Savings      2014-04-20          Active     450000.0
# ...

# %% [markdown]
# ##### Slicing

# %%
x = df.iloc[2:6, 1:7]

# %%
x
# Out:
#   first_name last_name date_of_birth  gender           email_address  \
# 2       Amit     Kumar    1978-11-01    Male        amit.k@email.com
# 3     Anjali     Mehta    1995-02-18  Female  anjali.mehta@email.com
# 4    Sandeep     Verma    1980-06-30    Male     sandeep.v@email.com
# 5       Neha     Joshi    1990-09-05  Female    neha.joshi@email.com
#
#    phone_number
# 2  919765432109
# 3  919123456789
# 4  918877665544
# 5  919012345678

# %%
df.iloc[2:, :7]
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 2         C003       Amit     Kumar    1978-11-01    Male
# 3         C004     Anjali     Mehta    1995-02-18  Female
# 4         C005    Sandeep     Verma    1980-06-30    Male
# 5         C006       Neha     Joshi    1990-09-05  Female
# 6         C007     Vikram     Patel    1975-03-20    Male
# 7         C008      Sonia       Das    1988-10-10  Female
# 8         C009      Arjun     Yadav    1998-05-15    Male
# 9         C010    Deepika     Reddy    1991-01-20  Female
# 10        C011      Rahul     Gupta    1983-04-05    Male
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 12        C013     Mahesh     Dubey    1970-12-25    Male
# 13        C014      Pooja       Rao    1987-03-22  Female
# 14        C015      Vinay     Meena    1996-06-05    Male
# 15        C016      Priya       Das    1993-02-28  Female
# 16        C017      Akash   Mahadik    1989-10-15    Male
# ...

# %%
df.iloc[:, 1:6]
# Out:
#    first_name last_name date_of_birth  gender            email_address
# 0      Rajesh    Sharma    1985-04-12    Male  rajesh.sharma@email.com
# 1       Priya   Satpute    1992-07-25  Female  priya.satpute@email.com
# 2        Amit     Kumar    1978-11-01    Male         amit.k@email.com
# 3      Anjali     Mehta    1995-02-18  Female   anjali.mehta@email.com
# 4     Sandeep     Verma    1980-06-30    Male      sandeep.v@email.com
# 5        Neha     Joshi    1990-09-05  Female     neha.joshi@email.com
# 6      Vikram     Patel    1975-03-20    Male       vikram.p@email.com
# 7       Sonia       Das    1988-10-10  Female      sonia.das@email.com
# 8       Arjun     Yadav    1998-05-15    Male        arjun.y@email.com
# 9     Deepika     Reddy    1991-01-20  Female      deepika.r@email.com
# 10      Rahul     Gupta    1983-04-05    Male        rahul.g@email.com
# 11     Shruti   Agarwal    1994-08-11  Female       shruti.a@email.com
# ...

# %%
df.iloc[[5,2,12,8,17], 1:7]
# Out:
#    first_name last_name date_of_birth  gender         email_address  \
# 5        Neha     Joshi    1990-09-05  Female  neha.joshi@email.com
# 2        Amit     Kumar    1978-11-01    Male      amit.k@email.com
# 12     Mahesh     Dubey    1970-12-25    Male    mahesh.d@email.com
# 8       Arjun     Yadav    1998-05-15    Male     arjun.y@email.com
# 17       Ritu    Saxena    1984-01-08  Female      ritu.s@email.com
#
#     phone_number
# 5   919012345678
# 2   919765432109
# 12  918543210987
# 8   919345678901
# 17  918098765432

# %%
df.loc[3:15, 'first_name']
# Out:
# 3      Anjali
# 4     Sandeep
# 5        Neha
# 6      Vikram
# 7       Sonia
# 8       Arjun
# 9     Deepika
# 10      Rahul
# 11     Shruti
# 12     Mahesh
# 13      Pooja
# 14      Vinay
# 15      Priya
# Name: first_name, dtype: object

# %%
df.loc[3:15, ['first_name','last_name']]
# Out:
#    first_name last_name
# 3      Anjali     Mehta
# 4     Sandeep     Verma
# 5        Neha     Joshi
# 6      Vikram     Patel
# 7       Sonia       Das
# 8       Arjun     Yadav
# 9     Deepika     Reddy
# 10      Rahul     Gupta
# 11     Shruti   Agarwal
# 12     Mahesh     Dubey
# 13      Pooja       Rao
# 14      Vinay     Meena
# 15      Priya       Das

# %%
df[['first_name','last_name']]
# Out:
#    first_name last_name
# 0      Rajesh    Sharma
# 1       Priya   Satpute
# 2        Amit     Kumar
# 3      Anjali     Mehta
# 4     Sandeep     Verma
# 5        Neha     Joshi
# 6      Vikram     Patel
# 7       Sonia       Das
# 8       Arjun     Yadav
# 9     Deepika     Reddy
# 10      Rahul     Gupta
# 11     Shruti   Agarwal
# 12     Mahesh     Dubey
# 13      Pooja       Rao
# 14      Vinay     Meena
# 15      Priya       Das
# 16      Akash   Mahadik
# 17       Ritu    Saxena
# 18      Vivek     Yadav
# 19    Sanjana     Singh

# %%
df.first_name
# Out:
# 0      Rajesh
# 1       Priya
# 2        Amit
# 3      Anjali
# 4     Sandeep
# 5        Neha
# 6      Vikram
# 7       Sonia
# 8       Arjun
# 9     Deepika
# 10      Rahul
# 11     Shruti
# 12     Mahesh
# 13      Pooja
# 14      Vinay
# 15      Priya
# 16      Akash
# 17       Ritu
# 18      Vivek
# 19    Sanjana
# Name: first_name, dtype: object

# %%
df.drop(4)
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 0         C001     Rajesh    Sharma    1985-04-12    Male
# 1         C002      Priya   Satpute    1992-07-25  Female
# 2         C003       Amit     Kumar    1978-11-01    Male
# 3         C004     Anjali     Mehta    1995-02-18  Female
# 5         C006       Neha     Joshi    1990-09-05  Female
# 6         C007     Vikram     Patel    1975-03-20    Male
# 7         C008      Sonia       Das    1988-10-10  Female
# 8         C009      Arjun     Yadav    1998-05-15    Male
# 9         C010    Deepika     Reddy    1991-01-20  Female
# 10        C011      Rahul     Gupta    1983-04-05    Male
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 12        C013     Mahesh     Dubey    1970-12-25    Male
# 13        C014      Pooja       Rao    1987-03-22  Female
# 14        C015      Vinay     Meena    1996-06-05    Male
# 15        C016      Priya       Das    1993-02-28  Female
# ...

# %%
df.drop('gender', axis=1)
# Out:
#    customer_id first_name last_name date_of_birth            email_address  \
# 0         C001     Rajesh    Sharma    1985-04-12  rajesh.sharma@email.com
# 1         C002      Priya   Satpute    1992-07-25  priya.satpute@email.com
# 2         C003       Amit     Kumar    1978-11-01         amit.k@email.com
# 3         C004     Anjali     Mehta    1995-02-18   anjali.mehta@email.com
# 4         C005    Sandeep     Verma    1980-06-30      sandeep.v@email.com
# 5         C006       Neha     Joshi    1990-09-05     neha.joshi@email.com
# 6         C007     Vikram     Patel    1975-03-20       vikram.p@email.com
# 7         C008      Sonia       Das    1988-10-10      sonia.das@email.com
# 8         C009      Arjun     Yadav    1998-05-15        arjun.y@email.com
# 9         C010    Deepika     Reddy    1991-01-20      deepika.r@email.com
# 10        C011      Rahul     Gupta    1983-04-05        rahul.g@email.com
# ...

# %%
df['average_monthly_balance']
# Out:
# 0     165000
# 1      50000
# 2     150000
# 3      42750
# 4      15000
# 5     148500
# 6      25000
# 7      56000
# 8      45000
# 9      32000
# 10     15000
# 11    175000
# 12     50000
# 13     91000
# 14     75000
# 15     50000
# 16     98000
# 17     15000
# 18     65000
# 19     20000
# Name: average_monthly_balance, dtype: int64

# %%
df['average_monthly_balance'].min()
# Out:
# 15000

# %%
df['average_monthly_balance'].mean()
# Out:
# 69162.5

# %%
df['average_monthly_balance'].median()
# Out:
# 50000.0

# %%
df['average_monthly_balance'].sum()
# Out:
# 1383250

# %%
df['average_monthly_balance'].max()
# Out:
# 175000

# %%
df['average_monthly_balance']
# Out:
# 0     165000
# 1      50000
# 2     150000
# 3      42750
# 4      15000
# 5     148500
# 6      25000
# 7      56000
# 8      45000
# 9      32000
# 10     15000
# 11    175000
# 12     50000
# 13     91000
# 14     75000
# 15     50000
# 16     98000
# 17     15000
# 18     65000
# 19     20000
# Name: average_monthly_balance, dtype: int64

# %%
df['average_monthly_balance'] / 87.37
# Out:
# 0     1888.520087
# 1      572.278814
# 2     1716.836443
# 3      489.298386
# 4      171.683644
# 5     1699.668078
# 6      286.139407
# 7      640.952272
# 8      515.050933
# 9      366.258441
# 10     171.683644
# 11    2002.975850
# 12     572.278814
# 13    1041.547442
# 14     858.418221
# 15     572.278814
# 16    1121.666476
# 17     171.683644
# 18     743.962459
# 19     228.911526
# Name: average_monthly_balance, dtype: float64

# %%
df['usd_value'] = df['average_monthly_balance'] / 87.37

# %%
df
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 0         C001     Rajesh    Sharma    1985-04-12    Male
# 1         C002      Priya   Satpute    1992-07-25  Female
# 2         C003       Amit     Kumar    1978-11-01    Male
# 3         C004     Anjali     Mehta    1995-02-18  Female
# 4         C005    Sandeep     Verma    1980-06-30    Male
# 5         C006       Neha     Joshi    1990-09-05  Female
# 6         C007     Vikram     Patel    1975-03-20    Male
# 7         C008      Sonia       Das    1988-10-10  Female
# 8         C009      Arjun     Yadav    1998-05-15    Male
# 9         C010    Deepika     Reddy    1991-01-20  Female
# 10        C011      Rahul     Gupta    1983-04-05    Male
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 12        C013     Mahesh     Dubey    1970-12-25    Male
# 13        C014      Pooja       Rao    1987-03-22  Female
# 14        C015      Vinay     Meena    1996-06-05    Male
# ...

# %% [markdown]
# ##### Boolean filtering

# %%
df['average_monthly_balance'] > 90000
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# Name: average_monthly_balance, dtype: bool

# %%
df[df['average_monthly_balance'] > 90000]
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 0         C001     Rajesh    Sharma    1985-04-12    Male
# 2         C003       Amit     Kumar    1978-11-01    Male
# 5         C006       Neha     Joshi    1990-09-05  Female
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 13        C014      Pooja       Rao    1987-03-22  Female
# 16        C017      Akash   Mahadik    1989-10-15    Male
#
#               email_address  phone_number address_line1          city  \
# 0   rajesh.sharma@email.com  919876543210            12     Sector 15
# 2          amit.k@email.com  919765432109             7   Park Street
# 5      neha.joshi@email.com  919012345678             5          Juhu
# 11       shruti.a@email.com  918654321098            16   Civil Lines
# 13      pooja.rao@email.com  918432109876            14   Koramangala
# 16        akash.m@email.com  918109876543             6  Adarsh Nagar
#
# ...

# %%
x = df[(df['average_monthly_balance'] > 90000) & (df['gender'] == 'Female')]
x
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 5         C006       Neha     Joshi    1990-09-05  Female
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 13        C014      Pooja       Rao    1987-03-22  Female
#
#            email_address  phone_number address_line1         city      state  \
# 5   neha.joshi@email.com  919012345678             5         Juhu     Mumbai
# 11    shruti.a@email.com  918654321098            16  Civil Lines    Lucknow
# 13   pooja.rao@email.com  918432109876            14  Koramangala  Bengaluru
#
#     ... account_status  current_balance balance_date last_activity_date  \
# 5   ...     2012-04-03           Active     31500.50         2025-08-29
# 11  ...     2016-06-08           Active     45000.75         2025-08-29
# 13  ...     2011-09-30           Active     59000.40         2025-08-29
#
#    total_deposits_ytd total_withdrawals_ytd average_monthly_balance  \
# ...

# %%
high = df[df['average_monthly_balance'] == df['average_monthly_balance'].max()]
high[['first_name','last_name']]
# Out:
#    first_name last_name
# 11     Shruti   Agarwal

# %%
x
# Out:
#    customer_id first_name last_name date_of_birth  gender  \
# 5         C006       Neha     Joshi    1990-09-05  Female
# 11        C012     Shruti   Agarwal    1994-08-11  Female
# 13        C014      Pooja       Rao    1987-03-22  Female
#
#            email_address  phone_number address_line1         city      state  \
# 5   neha.joshi@email.com  919012345678             5         Juhu     Mumbai
# 11    shruti.a@email.com  918654321098            16  Civil Lines    Lucknow
# 13   pooja.rao@email.com  918432109876            14  Koramangala  Bengaluru
#
#     ... account_status  current_balance balance_date last_activity_date  \
# 5   ...     2012-04-03           Active     31500.50         2025-08-29
# 11  ...     2016-06-08           Active     45000.75         2025-08-29
# 13  ...     2011-09-30           Active     59000.40         2025-08-29
#
#    total_deposits_ytd total_withdrawals_ytd average_monthly_balance  \
# ...

# %%
x.to_csv('prime-accounts.csv', index=False)
